# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Зачем мы это прикрепили?

# %% [markdown]
# После парсинга значения странБ режиссеров и актеров неровно легли в таблице к фильму, поэтому ниже мы провели все данные по фильмам в одну строчку + разделили всю информацию по столбцам для удобной работы.

# %%
import pickle
import pandas as pd

df = pd.read_csv('final.csv', sep=',')
df = df.set_index('Unnamed: 0')
df
# Out:
#                          Name  Rate  \
# Unnamed: 0
# 0           Побег из Шоушенка   9.1
# 1                Зеленая миля   9.1
# 2                Форрест Гамп   8.9
# 3             Список Шиндлера   8.8
# 4                         1+1   8.8
# ...                       ...   ...
# 94                        NaN   NaN
# 95                        NaN   NaN
# 96                        NaN   NaN
# 97                        NaN   NaN
# 98                        NaN   NaN
#
#                                                    Info     View    Year  \
# Unnamed: 0
# 0                 США • драма  Режиссёр: Фрэнк Дарабонт  920 397  1994.0
# 1                   В ролях: Тим Роббинс, Морган Фриман  890 554  1999.0
# 2                 США • драма  Режиссёр: Фрэнк Дарабонт  817 092  1994.0
# 3                        В ролях: Том Хэнкс, Дэвид Морс  476 692  1993.0
# 4                 США • драма  Режиссёр: Роберт Земекис   1 575K  2011.0
# ...

# %%
df.iloc[1959:1961]
# Out:
#            Name  Rate                                              Info View  \
# Unnamed: 0
# 60          NaN   NaN                                     США • фэнтези  NaN
# 61          NaN   NaN  Мексика • ужасы  Режиссёр: Адриан Гарсиа Больяно  NaN
#
#             Year  Duration
# Unnamed: 0
# 60           NaN       NaN
# 61           NaN       NaN

# %%
df1 = df[:100]
df2 = df.iloc[100:200]
df3 = df.iloc[200:299] # пропуск 268 строка
df4 = df.iloc[299:399]
df5 = df.iloc[399:499]
df6 = df.iloc[499:599]
df7 = df.iloc[599:699]
df8 = df.iloc[699:799]
df9 = df.iloc[799:899]
df10 = df.iloc[899:999]
df11 = df.iloc[999:1099]
df12 = df.iloc[1099:1199]
df13 = df.iloc[1199:1299]
df14 = df.iloc[1299:1399]
df15 = df.iloc[1399:1499]
df16 = df.iloc[1499:1599]
df17 = df.iloc[1599:1699]
df18 = df.iloc[1699:1799]
df19 = df.iloc[1799:1899]
df20 = df.iloc[1899:1998] # пропуск 1960 строка

df2
# Out:
#                                                          Name  Rate  \
# Unnamed: 0
# 0           Пираты Карибского моря: Проклятие Черной жемчу...   8.4
# 1                                                      ВАЛЛ·И   8.4
# 2                                                 Одержимость   8.4
# 3                                   Терминатор 2: Судный день   8.3
# 4                                              Молчание ягнят   8.3
# ...                                                       ...   ...
# 95                                                        NaN   NaN
# 96                                                        NaN   NaN
# 97                                                        NaN   NaN
# 98                                                        NaN   NaN
# 99                                                        NaN   NaN
#
#                                                    Info     View    Year  \
# Unnamed: 0
# ...

# %%
dfs1 = df1['Info']
dfS1 = pd.DataFrame(dfs1)
df_o1 = dfS1.iloc [1: , :]
df_countries1 = df_o1[::2]
df_countries1 = df_countries1.reset_index(drop=True)

df_roles1 = dfS1[::2]
df_roles1 = df_roles1.reset_index(drop=True)

resultP1 = pd.concat([df_countries1, df_roles1], axis=1)
resultP1
# Out:
#                                                 Info  \
# 0                В ролях: Тим Роббинс, Морган Фриман
# 1                     В ролях: Том Хэнкс, Дэвид Морс
# 2                     В ролях: Том Хэнкс, Робин Райт
# 3                   В ролях: Лиам Нисон, Бен Кингсли
# 4                    В ролях: Франсуа Клюзе, Омар Си
# 5        В ролях: Александр Демьяненко, Юрий Яковлев
# 6           В ролях: Мэттью Бродерик, Джереми Айронс
# 7     В ролях: Энтони Гонсалес, Гаэль Гарсиа Берналь
# 8            В ролях: Леонид Быков, Сергей Подгорный
# 9                 В ролях: Марлон Брандо, Аль Пачино
# 10                 В ролях: Жан Рено, Натали Портман
# 11  В ролях: Леонардо ДиКаприо, Джозеф Гордон-Левитт
# 12                 В ролях: Эдвард Нортон, Брэд Питт
# 13          В ролях: Джейсон Шварцман, Дж.К. Симмонс
# 14             В ролях: Элайджа Вуд, Вигго Мортенсен
# 15         В ролях: Джон Траволта, Сэмюэл Л. Джексон
# 16          В ролях: Майкл Дж. Фокс, Кристофер Ллойд
# ...

# %%
dfM1 = df1.drop('Info', axis=1, inplace=True)
# Out:
# /Users/nikitabutov/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dfM1 = df1.iloc[:50]
finalP1 = pd.concat([resultP1, dfM1], axis=1)
finalP1
# Out:
#                                                 Info  \
# 0                В ролях: Тим Роббинс, Морган Фриман
# 1                     В ролях: Том Хэнкс, Дэвид Морс
# 2                     В ролях: Том Хэнкс, Робин Райт
# 3                   В ролях: Лиам Нисон, Бен Кингсли
# 4                    В ролях: Франсуа Клюзе, Омар Си
# 5        В ролях: Александр Демьяненко, Юрий Яковлев
# 6           В ролях: Мэттью Бродерик, Джереми Айронс
# 7     В ролях: Энтони Гонсалес, Гаэль Гарсиа Берналь
# 8            В ролях: Леонид Быков, Сергей Подгорный
# 9                 В ролях: Марлон Брандо, Аль Пачино
# 10                 В ролях: Жан Рено, Натали Портман
# 11  В ролях: Леонардо ДиКаприо, Джозеф Гордон-Левитт
# 12                 В ролях: Эдвард Нортон, Брэд Питт
# 13          В ролях: Джейсон Шварцман, Дж.К. Симмонс
# 14             В ролях: Элайджа Вуд, Вигго Мортенсен
# 15         В ролях: Джон Траволта, Сэмюэл Л. Джексон
# 16          В ролях: Майкл Дж. Фокс, Кристофер Ллойд
# ...

# %%
dfs2 = df2['Info']
dfS2 = pd.DataFrame(dfs2)
df_o2 = dfS2.iloc [1: , :]
df_countries2 = df_o2[::2]
df_countries2 = df_countries2.reset_index(drop=True)

df_roles2 = dfS2[::2]
df_roles2 = df_roles2.reset_index(drop=True)

resultP2 = pd.concat([df_countries2, df_roles2], axis=1)
resultP2
# Out:
#                                              Info  \
# 0               В ролях: Джонни Депп, Джеффри Раш
# 1                 В ролях: Бен Бертт, Элисса Найт
# 2            В ролях: Майлз Теллер, Дж.К. Симмонс
# 3   В ролях: Арнольд Шварценеггер, Линда Хэмилтон
# 4           В ролях: Джоди Фостер, Энтони Хопкинс
# 5              В ролях: Тиэко Байсё, Такуя Кимура
# 6     В ролях: Татьяна Самойлова, Алексей Баталов
# 7      В ролях: Джиннифер Гудвин, Джейсон Бейтман
# 8              В ролях: Тори Келли, Риз Уизерспун
# 9          В ролях: Эдвард Нортон, Эдвард Ферлонг
# 10              В ролях: Брэд Питт, Морган Фриман
# 11   В ролях: Сергей Бодров мл., Виктор Сухоруков
# 12                В ролях: Мэл Гибсон, Софи Марсо
# 13       В ролях: Арслан Крымчурин, Марта Кесслер
# 14              В ролях: Маколей Калкин, Джо Пеши
# 15                В ролях: Джим Керри, Лора Линни
# 16           В ролях: Роберт Де Ниро, Джеймс Вудс
# 17         В ролях: Дэниэл Рэдклифф, Руперт Гринт
# ...

# %%
dfM2 = df2.drop('Info', axis=1, inplace=True)
# Out:
# /Users/nikitabutov/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dfM2 = df2.iloc[:50]
finalP2 = pd.concat([resultP2, dfM2], axis=1)
finalP2
# Out:
#                                              Info  \
# 0               В ролях: Джонни Депп, Джеффри Раш
# 1                 В ролях: Бен Бертт, Элисса Найт
# 2            В ролях: Майлз Теллер, Дж.К. Симмонс
# 3   В ролях: Арнольд Шварценеггер, Линда Хэмилтон
# 4           В ролях: Джоди Фостер, Энтони Хопкинс
# 5              В ролях: Тиэко Байсё, Такуя Кимура
# 6     В ролях: Татьяна Самойлова, Алексей Баталов
# 7      В ролях: Джиннифер Гудвин, Джейсон Бейтман
# 8              В ролях: Тори Келли, Риз Уизерспун
# 9          В ролях: Эдвард Нортон, Эдвард Ферлонг
# 10              В ролях: Брэд Питт, Морган Фриман
# 11   В ролях: Сергей Бодров мл., Виктор Сухоруков
# 12                В ролях: Мэл Гибсон, Софи Марсо
# 13       В ролях: Арслан Крымчурин, Марта Кесслер
# 14              В ролях: Маколей Калкин, Джо Пеши
# 15                В ролях: Джим Керри, Лора Линни
# 16           В ролях: Роберт Де Ниро, Джеймс Вудс
# 17         В ролях: Дэниэл Рэдклифф, Руперт Гринт
# ...

# %%
dfs3 = df3['Info']
dfS3 = pd.DataFrame(dfs3)
dfS31 = dfS3.iloc[:67]
dfS32 = dfS3.iloc[67:]
dfS311 = pd.DataFrame(['-'])
df_31 = pd.concat([dfS31, dfS311], axis=0)
df33 = pd.concat([df_31, dfS32])
df33
# Out:
#                                                 Info    0
# 0   Великобритания • драма  Режиссёр: Мартин Макдона  NaN
# 1           В ролях: Фрэнсис Макдорманд, Сэм Рокуэлл  NaN
# 2      США • военный  Режиссёр: Фрэнсис Форд Коппола  NaN
# 3                 В ролях: Марлон Брандо, Мартин Шин  NaN
# 4             США • драма  Режиссёр: Джозеф Косински  NaN
# ..                                               ...  ...
# 94        В ролях: Евгений Миронов, Владислав Галкин  NaN
# 95                 США • драма  Режиссёр: Роб Райнер  NaN
# 96             В ролях: Джек Николсон, Морган Фриман  NaN
# 97          Россия • военный  Режиссёр: Вадим Шмелев  NaN
# 98         В ролях: Алексей Бардуков, Евгений Дятлов  NaN
#
# [100 rows x 2 columns]

# %%
dfS_33 = df33.drop([0], axis=1)

# %%
dfS_33 = pd.DataFrame(dfS_33)
dfS_33
# Out:
#                                                 Info
# 0   Великобритания • драма  Режиссёр: Мартин Макдона
# 1           В ролях: Фрэнсис Макдорманд, Сэм Рокуэлл
# 2      США • военный  Режиссёр: Фрэнсис Форд Коппола
# 3                 В ролях: Марлон Брандо, Мартин Шин
# 4             США • драма  Режиссёр: Джозеф Косински
# ..                                               ...
# 94        В ролях: Евгений Миронов, Владислав Галкин
# 95                 США • драма  Режиссёр: Роб Райнер
# 96             В ролях: Джек Николсон, Морган Фриман
# 97          Россия • военный  Режиссёр: Вадим Шмелев
# 98         В ролях: Алексей Бардуков, Евгений Дятлов
#
# [100 rows x 1 columns]

# %%
df_o3 = dfS_33.iloc [1: , :]
df_countries3 = df_o3[::2]
df_countries3 = df_countries3.reset_index(drop=True)

df_roles3 = dfS_33[::2]
df_roles3 = df_roles3.reset_index(drop=True)

resultP3 = pd.concat([df_countries3, df_roles3], axis=1)
resultP3
# Out:
#                                                  Info  \
# 0            В ролях: Фрэнсис Макдорманд, Сэм Рокуэлл
# 1                  В ролях: Марлон Брандо, Мартин Шин
# 2                  В ролях: Джош Бролин, Майлз Теллер
# 3                  В ролях: Джонни Депп, Орландо Блум
# 4                В ролях: Билл Мюррей, Энди Макдауэлл
# 5                  В ролях: Шамеик Мур, Джейк Джонсон
# 6                 В ролях: Сёта Сомэтани, Кодзи Якусё
# 7                 В ролях: Джон Гудман, Билли Кристал
# 8                В ролях: Кая Киёхара, Таиси Накагава
# 9              В ролях: Дэниэл Рэдклифф, Руперт Гринт
# 10                В ролях: Роберт Де Ниро, Рэй Лиотта
# 11                В ролях: Джош Хартнетт, Брюс Уиллис
# 12                   В ролях: Майк Майерс, Эдди Мерфи
# 13                В ролях: Марк Хэмилл, Харрисон Форд
# 14              В ролях: Том Хэнкс, Кэтрин Зета-Джонс
# 15                    В ролях: Харви Кейтель, Тим Рот
# ...

# %%
dfM3 = df3.drop('Info', axis=1, inplace=True)
# Out:
# /Users/nikitabutov/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dfM3 = df3.iloc[:50]
finalP3 = pd.concat([resultP3, dfM3], axis=1)
finalP3
# Out:
#                                                  Info  \
# 0            В ролях: Фрэнсис Макдорманд, Сэм Рокуэлл
# 1                  В ролях: Марлон Брандо, Мартин Шин
# 2                  В ролях: Джош Бролин, Майлз Теллер
# 3                  В ролях: Джонни Депп, Орландо Блум
# 4                В ролях: Билл Мюррей, Энди Макдауэлл
# 5                  В ролях: Шамеик Мур, Джейк Джонсон
# 6                 В ролях: Сёта Сомэтани, Кодзи Якусё
# 7                 В ролях: Джон Гудман, Билли Кристал
# 8                В ролях: Кая Киёхара, Таиси Накагава
# 9              В ролях: Дэниэл Рэдклифф, Руперт Гринт
# 10                В ролях: Роберт Де Ниро, Рэй Лиотта
# 11                В ролях: Джош Хартнетт, Брюс Уиллис
# 12                   В ролях: Майк Майерс, Эдди Мерфи
# 13                В ролях: Марк Хэмилл, Харрисон Форд
# 14              В ролях: Том Хэнкс, Кэтрин Зета-Джонс
# 15                    В ролях: Харви Кейтель, Тим Рот
# ...

# %%
dfs4 = df4['Info']
dfS4 = pd.DataFrame(dfs4)
df_o4 = dfS4.iloc [1: , :]
df_countries4 = df_o4[::2]
df_countries4 = df_countries4.reset_index(drop=True)

df_roles4 = dfS4[::2]
df_roles4 = df_roles4.reset_index(drop=True)

resultP4 = pd.concat([df_countries4, df_roles4], axis=1)
resultP4
# Out:
#                                             Info  \
# 0           В ролях: Джефф Бриджес, Маккензи Фой
# 1              В ролях: Пэттон Освальт, Иэн Холм
# 2                  В ролях: Брэд Питт, Эрик Бана
# 3              В ролях: Джим Керри, Кейт Уинслет
# 4            В ролях: Рэй Романо, Джон Легуизамо
# 5              В ролях: Алексей Чадов, Иэн Келли
# 6            В ролях: Аль Пачино, Роберт Де Ниро
# 7           В ролях: Джейк Джилленхол, Лора Дерн
# 8             В ролях: Джоэл Эдгертон, Том Харди
# 9           В ролях: Джеймс Марсден, Гари Олдман
# 10               В ролях: Джош Гад, Деннис Куэйд
# 11        В ролях: Кира Найтли, Мэттью Макфэдиен
# 12           В ролях: Ричард Гир, Джулия Робертс
# 13               В ролях: Сон Кан-хо, Ли Сон-гюн
# 14             В ролях: НТР мл., Рам Чаран Теджа
# 15           В ролях: Том Шиллинг, Себастьян Кох
# 16    В ролях: Алексей Копашов, Андрей Мерзликин
# 17       В ролях: Мартин Фриман, Ричард Армитедж
# ...

# %%
dfM4 = df4.drop('Info', axis=1, inplace=True)
# Out:
# /Users/nikitabutov/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dfM4 = df4.iloc[:50]
finalP4 = pd.concat([resultP4, dfM4], axis=1)
finalP4
# Out:
#                                             Info  \
# 0           В ролях: Джефф Бриджес, Маккензи Фой
# 1              В ролях: Пэттон Освальт, Иэн Холм
# 2                  В ролях: Брэд Питт, Эрик Бана
# 3              В ролях: Джим Керри, Кейт Уинслет
# 4            В ролях: Рэй Романо, Джон Легуизамо
# 5              В ролях: Алексей Чадов, Иэн Келли
# 6            В ролях: Аль Пачино, Роберт Де Ниро
# 7           В ролях: Джейк Джилленхол, Лора Дерн
# 8             В ролях: Джоэл Эдгертон, Том Харди
# 9           В ролях: Джеймс Марсден, Гари Олдман
# 10               В ролях: Джош Гад, Деннис Куэйд
# 11        В ролях: Кира Найтли, Мэттью Макфэдиен
# 12           В ролях: Ричард Гир, Джулия Робертс
# 13               В ролях: Сон Кан-хо, Ли Сон-гюн
# 14             В ролях: НТР мл., Рам Чаран Теджа
# 15           В ролях: Том Шиллинг, Себастьян Кох
# 16    В ролях: Алексей Копашов, Андрей Мерзликин
# 17       В ролях: Мартин Фриман, Ричард Армитедж
# ...

# %%
dfs5 = df5['Info']
dfS5 = pd.DataFrame(dfs5)
df_o5 = dfS5.iloc [1: , :]
df_countries5 = df_o5[::2]
df_countries5 = df_countries5.reset_index(drop=True)

df_roles5 = dfS5[::2]
df_roles5 = df_roles5.reset_index(drop=True)

resultP5 = pd.concat([df_countries5, df_roles5], axis=1)

# %%
dfM5 = df5.drop('Info', axis=1, inplace=True)
# Out:
# /Users/nikitabutov/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dfM5 = df5.iloc[:50]
finalP5 = pd.concat([resultP5, dfM5], axis=1)
finalP5
# Out:
#                                               Info  \
# 0            В ролях: Джей Барушель, Кейт Бланшетт
# 1                 В ролях: Мэнди Мур, Закари Ливай
# 2         В ролях: Роберт Дауни мл., Джефф Бриджес
# 3               В ролях: Бен Аффлек, Розамунд Пайк
# 4                 В ролях: Котаро Дайго, Нана Мори
# 5                     В ролях: Том Холланд, Зендея
# 6              В ролях: Крис Эванс, Маккенна Грейс
# 7               В ролях: Джордж Клуни, Мэрил Стрип
# 8      В ролях: Тараджи П. Хенсон, Октавия Спенсер
# 9              В ролях: Юэн Макгрегор, Юэн Бремнер
# 10          В ролях: Дэниэл Рэдклифф, Руперт Гринт
# 11        В ролях: Леонардо ДиКаприо, Тоби Магуайр
# 12                  В ролях: Том Круз, Эмили Блант
# 13        В ролях: Альберт Брукс, Эллен ДеДженерес
# 14        В ролях: Сами Насери, Фредерик Дифенталь
# 15                В ролях: Крис Пайн, Алек Болдуин
# 16              В ролях: Рэйф Файнс, Тони Револори
# ...

# %%
dfs6 = df6['Info']
dfS6 = pd.DataFrame(dfs6)
df_o6 = dfS6.iloc [1: , :]
df_countries6 = df_o6[::2]
df_countries6 = df_countries6.reset_index(drop=True)

df_roles6 = dfS6[::2]
df_roles6 = df_roles6.reset_index(drop=True)

resultP6 = pd.concat([df_countries6, df_roles6], axis=1)

# %%
dfM6 = df6.drop('Info', axis=1, inplace=True)
# Out:
# /Users/nikitabutov/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dfM6 = df6.iloc[:50]
finalP6 = pd.concat([resultP6, dfM6], axis=1)
finalP6
# Out:
#                                              Info  \
# 0          В ролях: Джессика Честейн, Марк Стронг
# 1        В ролях: Леонардо ДиКаприо, Марк Уолберг
# 2          В ролях: Джерард Батлер, Том Уилкинсон
# 3                 В ролях: Бен Аффлек, Галь Гадот
# 4             В ролях: Ольга Лерман, такса Таисия
# 5                В ролях: Том Харди, Шарлиз Терон
# 6          В ролях: Энтони Хопкинс, Оливия Колман
# 7             В ролях: Дэниэл Дэй-Льюис, Пол Дано
# 8               В ролях: Марио Касас, Ана Вахенер
# 9                     В ролях: Сэм Нил, Лора Дерн
# 10        В ролях: Юра Борисов, Тимофей Трибунцев
# 11              В ролях: Джим Керри, Зои Дешанель
# 12          В ролях: Брендан Фрейзер, Рэйчел Вайс
# 13              В ролях: Эдриан Броуди, Сами Гэйл
# 14             В ролях: Джек Блэк, Дастин Хоффман
# 15         В ролях: Аулии Кравальо, Дуэйн Джонсон
# 16     В ролях: Бруно Ганц, Александра Мария Лара
# 17           В ролях: Томми Ли Джонс, Джош Бролин
# ...

# %%
dfs7 = df7['Info']
dfS7 = pd.DataFrame(dfs7)
df_o7 = dfS7.iloc [1: , :]
df_countries7 = df_o7[::2]
df_countries7 = df_countries7.reset_index(drop=True)

df_roles7 = dfS7[::2]
df_roles7 = df_roles7.reset_index(drop=True)

resultP7 = pd.concat([df_countries7, df_roles7], axis=1)

# %%
dfM7 = df7.drop('Info', axis=1, inplace=True)
# Out:
# /Users/nikitabutov/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dfM7 = df7.iloc[:50]
finalP7 = pd.concat([resultP7, dfM7], axis=1)
finalP7
# Out:
#                                              Info  \
# 0          В ролях: Джессика Честейн, Марк Стронг
# 1        В ролях: Леонардо ДиКаприо, Марк Уолберг
# 2          В ролях: Джерард Батлер, Том Уилкинсон
# 3                 В ролях: Бен Аффлек, Галь Гадот
# 4             В ролях: Ольга Лерман, такса Таисия
# 5                В ролях: Том Харди, Шарлиз Терон
# 6          В ролях: Энтони Хопкинс, Оливия Колман
# 7             В ролях: Дэниэл Дэй-Льюис, Пол Дано
# 8               В ролях: Марио Касас, Ана Вахенер
# 9                     В ролях: Сэм Нил, Лора Дерн
# 10        В ролях: Юра Борисов, Тимофей Трибунцев
# 11              В ролях: Джим Керри, Зои Дешанель
# 12          В ролях: Брендан Фрейзер, Рэйчел Вайс
# 13              В ролях: Эдриан Броуди, Сами Гэйл
# 14             В ролях: Джек Блэк, Дастин Хоффман
# 15         В ролях: Аулии Кравальо, Дуэйн Джонсон
# 16     В ролях: Бруно Ганц, Александра Мария Лара
# 17           В ролях: Томми Ли Джонс, Джош Бролин
# ...

# %%
dfs8 = df8['Info']
dfS8 = pd.DataFrame(dfs8)
df_o8 = dfS8.iloc [1: , :]
df_countries8 = df_o8[::2]
df_countries8 = df_countries8.reset_index(drop=True)

df_roles8 = dfS8[::2]
df_roles8 = df_roles8.reset_index(drop=True)

resultP8 = pd.concat([df_countries8, df_roles8], axis=1)

# %%
dfM8 = df8.drop('Info', axis=1, inplace=True)
# Out:
# /Users/nikitabutov/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dfM8 = df8.iloc[:50]
finalP8 = pd.concat([resultP8, dfM8], axis=1)
finalP8
# Out:
#                                              Info  \
# 0              В ролях: Уилл Смит, Мартин Лоуренс
# 1             В ролях: Брюс Уиллис, Эдвард Нортон
# 2               В ролях: Джеймс Франко, Кейт Мара
# 3           В ролях: Леонардо ДиКаприо, Брэд Питт
# 4             В ролях: Майкл Китон, Эдвард Нортон
# 5      В ролях: Хоакин Феникс, Скарлетт Йоханссон
# 6                 В ролях: Орландо Блум, Ева Грин
# 7              В ролях: Тайлер Лабин, Алан Тьюдик
# 8     В ролях: Джозеф Гордон-Левитт, Зои Дешанель
# 9            В ролях: Джеймс МакЭвой, Джейми Белл
# 10      В ролях: Бенедикт Камбербэтч, Кира Найтли
# 11            В ролях: Трэвис Фиммел, Пола Пэттон
# 12           В ролях: Брюс Кэмпбелл, Эмбет Дэвидц
# 13       В ролях: Гэбриел ЛаБелль, Мишель Уильямс
# 14   В ролях: Фрэнсис Макдорманд, Уильям Х. Мэйси
# 15  В ролях: Владимир Вдовиченков, Андрей Андреев
# 16       В ролях: Юлия Пересильд, Евгений Цыганов
# 17              В ролях: Майкл Питт, Брит Марлинг
# ...

# %%
dfs9 = df9['Info']
dfS9 = pd.DataFrame(dfs9)
df_o9 = dfS9.iloc [1: , :]
df_countries9 = df_o9[::2]
df_countries9 = df_countries9.reset_index(drop=True)

df_roles9 = dfS9[::2]
df_roles9 = df_roles9.reset_index(drop=True)

resultP9 = pd.concat([df_countries9, df_roles9], axis=1)

# %%
dfM9 = df9.drop('Info', axis=1, inplace=True)
# Out:
# /Users/nikitabutov/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dfM9 = df9.iloc[:50]
finalP9 = pd.concat([resultP9, dfM9], axis=1)
finalP9
# Out:
#                                                Info  \
# 0      В ролях: Александр Яценко, Сергей Маковецкий
# 1               В ролях: Хоакин Феникс, Вуди Норман
# 2          В ролях: Риз Уизерспун, Роберт Паттинсон
# 3                В ролях: Генри Кавилл, Арми Хаммер
# 4           В ролях: Милла Йовович, Мишель Родригес
# 5              В ролях: Ким Бейсингер, Алек Болдуин
# 6         В ролях: Мадс Миккельсен, Томас Бо Ларсен
# 7                  В ролях: Том Круз, Николь Кидман
# 8            В ролях: Кейт Бекинсейл, Скотт Спидман
# 9          В ролях: Кэтрин Моррис, Джонни Ли Миллер
# 10                       В ролях: Джон Чо, Сара Сон
# 11              В ролях: Крис Пайн, Мишель Родригес
# 12             В ролях: Джеффри Райт, Эдриан Броуди
# 13  В ролях: Джон Дэвид Вашингтон, Роберт Паттинсон
# 14     В ролях: Бенедикт Камбербэтч, Тильда Суинтон
# 15                В ролях: Чарли Ханнэм, Рами Малек
# 16              В ролях: Пётр Фёдоров, Анна Пескова
# ...

# %%
dfs10 = df10['Info']
dfS10 = pd.DataFrame(dfs10)
df_o10 = dfS10.iloc [1: , :]
df_countries10 = df_o10[::2]
df_countries10 = df_countries10.reset_index(drop=True)

df_roles10 = dfS10[::2]
df_roles10 = df_roles10.reset_index(drop=True)

resultP10 = pd.concat([df_countries10, df_roles10], axis=1)

# %%
dfM10 = df10.drop('Info', axis=1, inplace=True)
# Out:
# /Users/nikitabutov/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dfM10 = df10.iloc[:50]
finalP10 = pd.concat([resultP10, dfM10], axis=1)
finalP10
# Out:
#                                              Info  \
# 0           В ролях: Крис Эванс, Роберт Дауни мл.
# 1         В ролях: Тоби Магуайр, Джейк Джилленхол
# 2              В ролях: Кейт Уинслет, Джош Бролин
# 3         В ролях: Алексей Чадов, Виталий Кищенко
# 4                В ролях: Брэд Питт, Логан Лерман
# 5                 В ролях: Зак Эфрон, Рассел Кроу
# 6            В ролях: Джейсон Стэйтем, Рэй Лиотта
# 7           В ролях: Райан Рейнольдс, Джоди Комер
# 8              В ролях: Ченнинг Татум, Итан Сапли
# 9       В ролях: Боб Оденкёрк, Алексей Серебряков
# 10             В ролях: Мэтт Дэймон, Адам Драйвер
# 11             В ролях: Джим Парсонс, Бен Элдридж
# 12          В ролях: Мэтт Дэймон, Джейсон Бейтман
# 13             В ролях: Алек Болдуин, Джина Дэвис
# 14         В ролях: Антонио Бандерас, Елена Анайя
# 15          В ролях: Джонни Депп, Фрэнк Ланджелла
# 16            В ролях: Кристиан Бэйл, Стив Карелл
# 17               В ролях: Валин Кэйн, Шазад Латиф
# ...

# %%
dfs11 = df11['Info']
dfS11 = pd.DataFrame(dfs11)
df_o11 = dfS11.iloc [1: , :]
df_countries11 = df_o11[::2]
df_countries11 = df_countries11.reset_index(drop=True)

df_roles11 = dfS11[::2]
df_roles11 = df_roles11.reset_index(drop=True)

resultP11 = pd.concat([df_countries11, df_roles11], axis=1)

# %%
dfM11 = df11.drop('Info', axis=1, inplace=True)
# Out:
# /Users/nikitabutov/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dfM11 = df11.iloc[:50]
finalP11 = pd.concat([resultP11, dfM11], axis=1)
finalP11
# Out:
#                                                 Info  \
# 0             В ролях: Сергей Гармаш, Ольга Кузьмина
# 1             В ролях: Финн Уайтхед, Том Глинн-Карни
# 2                В ролях: Оливия Колман, Рэйчел Вайс
# 3        В ролях: Джастин Тимберлейк, Аманда Сайфред
# 4                 В ролях: Харви Кейтель, Майкл Кейн
# 5                 В ролях: Эмилия Кларк, Сэм Клафлин
# 6                 В ролях: Нив Кэмпбелл, Кортни Кокс
# 7          В ролях: Тим Блейк Нельсон, Джеймс Франко
# 8           В ролях: Юэн Макгрегор, Ребекка Фергюсон
# 9                В ролях: Джек Блэк, Брайан Крэнстон
# 10                    В ролях: Крис Пратт, Чарли Дэй
# 11             В ролях: Райан Гослинг, Кэри Маллиган
# 12                  В ролях: Сэм Рокуэлл, Марк Мэрон
# 13          В ролях: Роберт Дауни мл., Крис Хемсворт
# 14        В ролях: Дженнифер Лоуренс, Джош Хатчерсон
# 15             В ролях: Лу де Лааж, Рафаэль Персонас
# 16        В ролях: Майкл Сера, Мэри Элизабет Уинстэд
# ...

# %%
dfs12 = df12['Info']
dfS12 = pd.DataFrame(dfs12)
df_o12 = dfS12.iloc [1: , :]
df_countries12 = df_o12[::2]
df_countries12 = df_countries12.reset_index(drop=True)

df_roles12 = dfS12[::2]
df_roles12 = df_roles12.reset_index(drop=True)

resultP12 = pd.concat([df_countries12, df_roles12], axis=1)

# %%
dfM12 = df12.drop('Info', axis=1, inplace=True)
# Out:
# /Users/nikitabutov/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dfM12 = df12.iloc[:50]
finalP12 = pd.concat([resultP12, dfM12], axis=1)
finalP12
# Out:
#                                               Info  \
# 0        В ролях: Джастин Тимберлейк, Райдер Аллен
# 1          В ролях: Эмили Блант, Бенисио Дель Торо
# 2        В ролях: Павел Табаков, Данила Козловский
# 3             В ролях: Джейк Джилленхол, Дар Салим
# 4             В ролях: Кейт Бланшетт, Ноэми Мерлан
# 5                 В ролях: Леди Гага, Адам Драйвер
# 6             В ролях: Джефф Бриджес, Синтия Эриво
# 7       В ролях: Чарли Ханнэм, Астрид Берже-Фрисби
# 8               В ролях: Адам Сэндлер, Джулия Фокс
# 9                       В ролях: Кон Ю, Ма Дон-сок
# 10                В ролях: Остин Батлер, Том Хэнкс
# 11          В ролях: Том Холланд, Роберт Дауни мл.
# 12  В ролях: Сергей Пускепалис, Александр Метёлкин
# 13             В ролях: Кристиан Бэйл, Уиллем Дефо
# 14          В ролях: Дензел Вашингтон, Гари Олдман
# 15     В ролях: Брайс Даллас Ховард, Хоакин Феникс
# 16                 В ролях: Ли Бён-хон, Сон Кан-хо
# ...

# %%
dfs13 = df13['Info']
dfS13 = pd.DataFrame(dfs13)
df_o13 = dfS13.iloc [1: , :]
df_countries13 = df_o13[::2]
df_countries13 = df_countries13.reset_index(drop=True)

df_roles13 = dfS13[::2]
df_roles13 = df_roles13.reset_index(drop=True)

resultP13 = pd.concat([df_countries13, df_roles13], axis=1)

# %%
dfM13 = df13.drop('Info', axis=1, inplace=True)
# Out:
# /Users/nikitabutov/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dfM13 = df13.iloc[:50]
finalP13 = pd.concat([resultP13, dfM13], axis=1)
finalP13
# Out:
#                                                  Info  \
# 0               В ролях: Николас Кейдж, Джулианна Мур
# 1             В ролях: Антонио Бандерас, Сальма Хайек
# 2                В ролях: Джейсон Стэйтем, Обри Плаза
# 3               В ролях: Марио Касас, Мария Вальверде
# 4           В ролях: Дженнифер Лоуренс, Хавьер Бардем
# 5                     В ролях: Пол Радд, Майкл Дуглас
# 6               В ролях: Роберт Паттинсон, Зои Кравиц
# 7              В ролях: Крис Хемсворт, Натали Портман
# 8                        В ролях: Сторм Рид, Ниа Лонг
# 9             В ролях: Тэрон Эджертон, Никита Ефремов
# 10             В ролях: Киану Ривз, Риккардо Скамарчо
# 11           В ролях: Том Холланд, Дональд Рэй Поллок
# 12                    В ролях: Кай Гетц, Сергей Марин
# 13                  В ролях: Крис Пратт, Дэйв Батиста
# 14              В ролях: Кифер Сазерленд, Пола Пэттон
# 15                 В ролях: Купер Хоффман, Алана Хаим
# ...

# %%
dfs14 = df14['Info']
dfS14 = pd.DataFrame(dfs14)
df_o14 = dfS14.iloc [1: , :]
df_countries14 = df_o14[::2]
df_countries14 = df_countries14.reset_index(drop=True)

df_roles14 = dfS14[::2]
df_roles14 = df_roles14.reset_index(drop=True)

resultP14 = pd.concat([df_countries14, df_roles14], axis=1)

# %%
dfM14 = df14.drop('Info', axis=1, inplace=True)
# Out:
# /Users/nikitabutov/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dfM14 = df14.iloc[:50]
finalP14 = pd.concat([resultP14, dfM14], axis=1)
finalP14
# Out:
#                                              Info  \
# 0              В ролях: Самара Уивинг, Адам Броди
# 1   В ролях: Алиса Фрейндлих, Валентина Теличкина
# 2          В ролях: Киллиан Мерфи, Роберт Де Ниро
# 3              В ролях: Эндрю Гарфилд, Эмма Стоун
# 4         В ролях: Аглая Тарасова, Борис Дергачев
# 5        В ролях: Роман Маякин, Лукерья Ильяшенко
# 6          В ролях: Джулия Робертс, Хавьер Бардем
# 7               В ролях: Майлз Теллер, Джона Хилл
# 8                В ролях: Зак Эфрон, Лили Коллинз
# 9              В ролях: Том Харди, Мишель Уильямс
# 10               В ролях: Джон Кьюсак, Аманда Пит
# 11                 В ролях: Айла Фишер, Эрик Бана
# 12               В ролях: Киану Ривз, Холли Берри
# 13                В ролях: Филлипа Су, Люк Брейси
# 14     В ролях: Сара Джессика Паркер, Ким Кэтролл
# 15          В ролях: Элио Джермано, Леонардо Лиди
# 16  В ролях: Алексей Серебряков, Всеволод Володин
# 17    В ролях: Джон Гудман, Мэри Элизабет Уинстэд
# ...

# %%
dfs15 = df15['Info']
dfS15 = pd.DataFrame(dfs15)
df_o15 = dfS15.iloc [1: , :]
df_countries15 = df_o15[::2]
df_countries15 = df_countries15.reset_index(drop=True)

df_roles15 = dfS15[::2]
df_roles15 = df_roles15.reset_index(drop=True)

resultP15 = pd.concat([df_countries15, df_roles15], axis=1)

# %%
dfM15 = df15.drop('Info', axis=1, inplace=True)
# Out:
# /Users/nikitabutov/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dfM15 = df15.iloc[:50]
finalP15 = pd.concat([resultP15, dfM15], axis=1)
finalP15
# Out:
#                                                 Info  \
# 0                    В ролях: Крис Эванс, Сон Кан-хо
# 1        В ролях: Александр Скарсгард, Николь Кидман
# 2                  В ролях: Патрик Уилсон, Роуз Бирн
# 3         В ролях: Скарлетт Йоханссон, Морган Фриман
# 4   В ролях: Грейс Кэролайн Карри, Вирджиния Гарднер
# 5                  В ролях: Шейлин Вудли, Тео Джеймс
# 6      В ролях: Александр Петров, Виктор Добронравов
# 7               В ролях: Рэйф Файнс, Аня Тейлор-Джой
# 8                  В ролях: Крис Эванс, Хейли Этвелл
# 9         В ролях: Аня Чиповская, Александр Горчилин
# 10                  В ролях: Майк Майерс, Эдди Мерфи
# 11                   В ролях: Чин Ги-джу, Ви Ха-джун
# 12       В ролях: Александр Кузнецов, Елена Ербакова
# 13             В ролях: Сандра Буллок, Кейт Бланшетт
# 14           В ролях: Брайан Крэнстон, Джеймс Франко
# 15                В ролях: Закари Ливай, Эшер Энджел
# 16              В ролях: Эмилио Эстевес, Мик Джаггер
# ...

# %%
dfs16 = df16['Info']
dfS16 = pd.DataFrame(dfs16)
df_o16 = dfS16.iloc [1: , :]
df_countries16 = df_o16[::2]
df_countries16 = df_countries16.reset_index(drop=True)

df_roles16 = dfS16[::2]
df_roles16 = df_roles16.reset_index(drop=True)

resultP16 = pd.concat([df_countries16, df_roles16], axis=1)

# %%
dfM16 = df16.drop('Info', axis=1, inplace=True)
# Out:
# /Users/nikitabutov/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dfM16 = df16.iloc[:50]
finalP16 = pd.concat([resultP16, dfM16], axis=1)
finalP16
# Out:
#                                                  Info  \
# 0          В ролях: Дженнифер Лоуренс, Джош Хатчерсон
# 1   В ролях: Чутимон Чынгчаренсукйинг, Нопачай Чай...
# 2                   В ролях: Эмма Робертс, Люк Брейси
# 3               В ролях: Павел Деревянко, Юра Борисов
# 4          В ролях: Андрей Смоляков, Дмитрий Шевченко
# 5                   В ролях: Марк Роули, Пекка Странг
# 6                      В ролях: Джек Вульф, Иван Реон
# 7                В ролях: Харрис Дикинсон, Шарлби Дин
# 8                       В ролях: Джо Таслим, Ико Уайс
# 9               В ролях: Мелани Лоран, Матьё Амальрик
# 10            В ролях: Дуэйн Джонсон, Райан Рейнольдс
# 11                 В ролях: Энн Хэтэуэй, Ребел Уилсон
# 12         В ролях: Павел Деревянко, Оксана Акиньшина
# 13       В ролях: Бенедикт Камбербэтч, Элизабет Олсен
# 14       В ролях: Алек Болдуин, Майлз Кристофер Бакши
# 15          В ролях: Колин Фаррелл, Джоди Тёрнер-Смит
# ...

# %%
dfs17 = df17['Info']
dfS17 = pd.DataFrame(dfs17)
df_o17 = dfS17.iloc [1: , :]
df_countries17 = df_o17[::2]
df_countries17 = df_countries17.reset_index(drop=True)

df_roles17 = dfS17[::2]
df_roles17 = df_roles17.reset_index(drop=True)

resultP17 = pd.concat([df_countries17, df_roles17], axis=1)

# %%
dfM17 = df17.drop('Info', axis=1, inplace=True)
# Out:
# /Users/nikitabutov/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dfM17 = df17.iloc[:50]
finalP17 = pd.concat([resultP17, dfM17], axis=1)
finalP17
# Out:
#                                                Info  \
# 0               В ролях: Джеймс Марсден, Джим Керри
# 1            В ролях: Юлия Хлынина, Фёдор Бондарчук
# 2           В ролях: Павел Прилучный, Павел Чинарёв
# 3                В ролях: Дэниэл Калуя, Кеке Палмер
# 4             В ролях: Дмитрий Нагиев, Ирина Пегова
# 5              В ролях: Анна Адамович, Юлия Хлынина
# 6              В ролях: Софи Марсо, Моника Беллуччи
# 7             В ролях: Крис Пратт, Ивонн Страховски
# 8       В ролях: Лорен ЛаВера, Дэвид Ховард Торнтон
# 9          В ролях: Марк Уолберг, Чиветель Эджиофор
# 10     В ролях: Александр Новиков, Николай Галлямов
# 11          В ролях: Мелисса Баррера, Дженна Ортега
# 12             В ролях: Альбан Ленуар, Эрик Кантона
# 13               В ролях: Сози Бэйкон, Кайл Галлнер
# 14     В ролях: Нуми Рапас, Хильмир Снайр Гвюднасон
# 15          В ролях: Дуэйн Джонсон, Джейсон Стэйтем
# 16               В ролях: Идрис Эльба, Синтия Эриво
# ...

# %%
dfs18 = df18['Info']
dfS18 = pd.DataFrame(dfs18)
df_o18 = dfS18.iloc [1: , :]
df_countries18 = df_o18[::2]
df_countries18 = df_countries18.reset_index(drop=True)

df_roles18 = dfS18[::2]
df_roles18 = df_roles18.reset_index(drop=True)

resultP18 = pd.concat([df_countries18, df_roles18], axis=1)

# %%
dfM18 = df18.drop('Info', axis=1, inplace=True)
# Out:
# /Users/nikitabutov/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dfM18 = df18.iloc[:50]
finalP18 = pd.concat([resultP18, dfM18], axis=1)
finalP18
# Out:
#                                                Info  \
# 0       В ролях: Клара Галле, Хулио Пенья Фернандес
# 1             В ролях: Рассел Кроу, Дэниэл Дзоватто
# 2                В ролях: Бриттани Эшворт, Бен Лэмб
# 3                   В ролях: Эдди Редмэйн, Джуд Лоу
# 4                В ролях: Закари Ливай, Эшер Энджел
# 5       В ролях: Катерина Шпица, Александр Горбатов
# 6                В ролях: Кевин Дюрант, Тейлор Грэй
# 7          В ролях: Джон Траволта, Джейми Ли Кёртис
# 8                       В ролях: Джеки У, Цюй Чусяо
# 9               В ролях: Пол Радд, Эванджелин Лилли
# 10              В ролях: Джо Элвин, Маргарет Куэлли
# 11            В ролях: Фрэнк Грилло, Романо Реджани
# 12           В ролях: Крис Хемсворт, Натали Портман
# 13           В ролях: Сергей Кемпо, Любовь Аксёнова
# 14           В ролях: Любовь Аксёнова, Денис Шведов
# 15         В ролях: Дженна Кэнелл, Саманта Скаффиди
# 16    В ролях: Джозефин Лэнгфорд, Хиро Файнс Тиффин
# ...

# %%
dfs19 = df19['Info']
dfS19 = pd.DataFrame(dfs18)
df_o19 = dfS19.iloc [1: , :]
df_countries19 = df_o19[::2]
df_countries19 = df_countries19.reset_index(drop=True)

df_roles19 = dfS19[::2]
df_roles19 = df_roles19.reset_index(drop=True)

resultP19 = pd.concat([df_countries19, df_roles19], axis=1)

# %%
dfM19 = df19.drop('Info', axis=1, inplace=True)
# Out:
# /Users/nikitabutov/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dfM19 = df19.iloc[:50]
finalP19 = pd.concat([resultP19, dfM19], axis=1)
finalP19
# Out:
#                                                Info  \
# 0       В ролях: Клара Галле, Хулио Пенья Фернандес
# 1             В ролях: Рассел Кроу, Дэниэл Дзоватто
# 2                В ролях: Бриттани Эшворт, Бен Лэмб
# 3                   В ролях: Эдди Редмэйн, Джуд Лоу
# 4                В ролях: Закари Ливай, Эшер Энджел
# 5       В ролях: Катерина Шпица, Александр Горбатов
# 6                В ролях: Кевин Дюрант, Тейлор Грэй
# 7          В ролях: Джон Траволта, Джейми Ли Кёртис
# 8                       В ролях: Джеки У, Цюй Чусяо
# 9               В ролях: Пол Радд, Эванджелин Лилли
# 10              В ролях: Джо Элвин, Маргарет Куэлли
# 11            В ролях: Фрэнк Грилло, Романо Реджани
# 12           В ролях: Крис Хемсворт, Натали Портман
# 13           В ролях: Сергей Кемпо, Любовь Аксёнова
# 14           В ролях: Любовь Аксёнова, Денис Шведов
# 15         В ролях: Дженна Кэнелл, Саманта Скаффиди
# 16    В ролях: Джозефин Лэнгфорд, Хиро Файнс Тиффин
# ...

# %%
df20.iloc[58:65]
# Out:
#            Name  Rate                                              Info View  \
# Unnamed: 0
# 58          NaN   NaN            США • комедия  Режиссёр: Джош Гринбаум  NaN
# 59          NaN   NaN                В ролях: Уилл Феррелл, Джейми Фокс  NaN
# 60          NaN   NaN                                     США • фэнтези  NaN
# 61          NaN   NaN  Мексика • ужасы  Режиссёр: Адриан Гарсиа Больяно  NaN
# 62          NaN   NaN                В ролях: Мария Эволи, Рамон Медина  NaN
# 63          NaN   NaN    Финляндия • военный  Режиссёр: Ялмари Хеландер  NaN
# 64          NaN   NaN              В ролях: Йорма Томмила, Аксель Хенни  NaN
#
#             Year  Duration
# Unnamed: 0
# 58           NaN       NaN
# 59           NaN       NaN
# 60           NaN       NaN
# 61           NaN       NaN
# 62           NaN       NaN
# 63           NaN       NaN
# 64           NaN       NaN

# %%
df20.iloc[:61]
# Out:
#                              Name  Rate  \
# Unnamed: 0
# 0             Мавка. Лесная песня   0.0
# 1                  Рыцари Зодиака   0.0
# 2                       Русалочка   0.0
# 3           Убийцы цветочной луны   0.0
# 4                       Форсаж 10   0.0
# ...                           ...   ...
# 56                            NaN   NaN
# 57                            NaN   NaN
# 58                            NaN   NaN
# 59                            NaN   NaN
# 60                            NaN   NaN
#
#                                                         Info View    Year  \
# Unnamed: 0
# 0           Украина • мультфильм  Режиссёр: Александра Рубан  0.0  2022.0
# 1                     В ролях: Артём Пивоваров, Елена Кравец  0.0  2023.0
# 2                  США • фэнтези  Режиссёр: Томаш Багиньский  0.0  2023.0
# 3                              В ролях: Макэню, Фамке Янссен  0.0  2023.0
# 4                       США • фэнтези  Режиссёр: Роб Маршалл  0.0  2023.0
# ...

# %%
dfs20 = df20['Info']
dfS20 = pd.DataFrame(dfs20)
dfS201 = dfS20.iloc[:61]
dfS202 = dfS20.iloc[61:]
dfS2011 = pd.DataFrame(['-'])
df_201 = pd.concat([dfS201, dfS2011], axis=0)
df203 = pd.concat([df_201, dfS202])
df203
# Out:
#                                                 Info    0
# 0   Украина • мультфильм  Режиссёр: Александра Рубан  NaN
# 1             В ролях: Артём Пивоваров, Елена Кравец  NaN
# 2          США • фэнтези  Режиссёр: Томаш Багиньский  NaN
# 3                      В ролях: Макэню, Фамке Янссен  NaN
# 4               США • фэнтези  Режиссёр: Роб Маршалл  NaN
# ..                                               ...  ...
# 94            В ролях: Джош Лукас, Фернанда Уррехола  NaN
# 95           США • драма  Режиссёр: Джеймс С. Страуз  NaN
# 96          В ролях: Приянка Чопра Джонас, Сэм Хьюэн  NaN
# 97       США • фантастика  Режиссёр: Андрес Мускетти  NaN
# 98                  В ролях: Эзра Миллер, Саша Калле  NaN
#
# [100 rows x 2 columns]

# %%
dfS_203 = df203.drop([0], axis=1)

# %%
dfS_203 = pd.DataFrame(dfS_203)
dfS_203
# Out:
#                                                 Info
# 0   Украина • мультфильм  Режиссёр: Александра Рубан
# 1             В ролях: Артём Пивоваров, Елена Кравец
# 2          США • фэнтези  Режиссёр: Томаш Багиньский
# 3                      В ролях: Макэню, Фамке Янссен
# 4               США • фэнтези  Режиссёр: Роб Маршалл
# ..                                               ...
# 94            В ролях: Джош Лукас, Фернанда Уррехола
# 95           США • драма  Режиссёр: Джеймс С. Страуз
# 96          В ролях: Приянка Чопра Джонас, Сэм Хьюэн
# 97       США • фантастика  Режиссёр: Андрес Мускетти
# 98                  В ролях: Эзра Миллер, Саша Калле
#
# [100 rows x 1 columns]

# %%
df_o20 = dfS_203.iloc [1: , :]
df_countries20 = df_o20[::2]
df_countries20 = df_countries20.reset_index(drop=True)

df_roles20 = dfS_203[::2]
df_roles20 = df_roles20.reset_index(drop=True)

resultP20 = pd.concat([df_countries20, df_roles20], axis=1)

# %%
dfM20 = df20.drop('Info', axis=1, inplace=True)
# Out:
# /Users/nikitabutov/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dfM20 = df20.iloc[:50]
finalP20 = pd.concat([resultP20, dfM20], axis=1)
finalP20
# Out:
#                                               Info  \
# 0           В ролях: Артём Пивоваров, Елена Кравец
# 1                    В ролях: Макэню, Фамке Янссен
# 2           В ролях: Холли Бейли, Джона Хауэр-Кинг
# 3       В ролях: Леонардо ДиКаприо, Роберт Де Ниро
# 4            В ролях: Вин Дизель, Джордана Брюстер
# 5              В ролях: Маккенна Грейс, Брэйди Нун
# 6          В ролях: Павел Табаков, Таисия Радченко
# 7                В ролях: Мишель Йео, Пит Дэвидсон
# 8          В ролях: Джош Хатчерсон, Мэттью Лиллард
# 9              В ролях: Арчи Мадекве, Орландо Блум
# 10    В ролях: Сильвестр Сталлоне, Джейсон Стэйтем
# 11              В ролях: Лана Кондор, Тони Коллетт
# 12      В ролях: Даша Верещагина, Марк Эйдельштейн
# 13   В ролях: Гакуто Кадзивара, Нобунага Симадзаки
# 14          В ролях: Джей Барушель, Гленн Хауэртон
# 15          В ролях: Сара Т. Коэн, Эмбер Дойг-Торн
# 16            В ролях: Дженна Ортега, Джастин Теру
# ...

# %%
final = pd.concat([finalP1, finalP2, finalP3, finalP4, finalP5, finalP6, finalP7, finalP8, finalP9, finalP10, finalP11, finalP12, finalP13, finalP14, finalP15, finalP16, finalP17, finalP18, finalP19, finalP20])

# %%
final = final.reset_index(drop=True)
final = final[['Name', 'Rate', 'Info', 'View', 'Year', 'Duration']]
final.columns = ['Name', 'Rate', 'Roles', 'Country', 'View', 'Year', 'Duration']
final
# Out:
#                                                Name  Rate  \
# 0                                 Побег из Шоушенка   9.1
# 1                                      Зеленая миля   9.1
# 2                                      Форрест Гамп   8.9
# 3                                   Список Шиндлера   8.8
# 4                                               1+1   8.8
# ..                                              ...   ...
# 995  Голодные игры: Баллада о змеях и певчих птицах   0.0
# 996          Леди Баг и Супер-Кот: Пробуждение силы   0.0
# 997                                       Мегалодон   0.0
# 998                                      Люби снова   0.0
# 999                                            Флэш   0.0
#
#                                              Roles  \
# 0              В ролях: Тим Роббинс, Морган Фриман
# 1                   В ролях: Том Хэнкс, Дэвид Морс
# 2                   В ролях: Том Хэнкс, Робин Райт
# 3                 В ролях: Лиам Нисон, Бен Кингсли
# ...

# %%
final.to_pickle('b_final.pkl')

# %%
final[['no', 'Roles']] = final['Roles'].str.split(': ', 1, expand= True)
final
# Out:
#                                                Name  Rate  \
# 0                                 Побег из Шоушенка   9.1
# 1                                      Зеленая миля   9.1
# 2                                      Форрест Гамп   8.9
# 3                                   Список Шиндлера   8.8
# 4                                               1+1   8.8
# ..                                              ...   ...
# 995  Голодные игры: Баллада о змеях и певчих птицах   0.0
# 996          Леди Баг и Супер-Кот: Пробуждение силы   0.0
# 997                                       Мегалодон   0.0
# 998                                      Люби снова   0.0
# 999                                            Флэш   0.0
#
#                                     Roles  \
# 0              Тим Роббинс, Морган Фриман
# 1                   Том Хэнкс, Дэвид Морс
# 2                   Том Хэнкс, Робин Райт
# 3                 Лиам Нисон, Бен Кингсли
# 4                  Франсуа Клюзе, Омар Си
# ...

# %%
final.drop('no', axis=1, inplace=True)

# %%
final
# Out:
#                                                Name  Rate  \
# 0                                 Побег из Шоушенка   9.1
# 1                                      Зеленая миля   9.1
# 2                                      Форрест Гамп   8.9
# 3                                   Список Шиндлера   8.8
# 4                                               1+1   8.8
# ..                                              ...   ...
# 995  Голодные игры: Баллада о змеях и певчих птицах   0.0
# 996          Леди Баг и Супер-Кот: Пробуждение силы   0.0
# 997                                       Мегалодон   0.0
# 998                                      Люби снова   0.0
# 999                                            Флэш   0.0
#
#                                     Roles  \
# 0              Тим Роббинс, Морган Фриман
# 1                   Том Хэнкс, Дэвид Морс
# 2                   Том Хэнкс, Робин Райт
# 3                 Лиам Нисон, Бен Кингсли
# 4                  Франсуа Клюзе, Омар Си
# ...

# %%
df = final

# %%
df
# Out:
#                                                Name  Rate  \
# 0                                 Побег из Шоушенка   9.1
# 1                                      Зеленая миля   9.1
# 2                                      Форрест Гамп   8.9
# 3                                   Список Шиндлера   8.8
# 4                                               1+1   8.8
# ..                                              ...   ...
# 995  Голодные игры: Баллада о змеях и певчих птицах   0.0
# 996          Леди Баг и Супер-Кот: Пробуждение силы   0.0
# 997                                       Мегалодон   0.0
# 998                                      Люби снова   0.0
# 999                                            Флэш   0.0
#
#                                     Roles  \
# 0              Тим Роббинс, Морган Фриман
# 1                   Том Хэнкс, Дэвид Морс
# 2                   Том Хэнкс, Робин Райт
# 3                 Лиам Нисон, Бен Кингсли
# 4                  Франсуа Клюзе, Омар Си
# ...

# %%
df[['Country', 'Other']] = df['Country'].str.split(' ', 1, expand= True)

# %%
df[['dot', 'Other']] = df['Other'].str.split(' ', 1, expand= True)

# %%
df[['Genre', 'Director']] = df['Other'].str.split(' ', 1, expand= True)

# %%
df.drop('dot', axis=1, inplace=True)

# %%
gen = df['Genre'].str.rstrip('  Режиссёр: ')

# %%
df = pd.concat([df, gen], axis=1)
df.columns = ['Name', 'Rate', 'Roles', 'Country', 'View', 'Year', 'Duration', 'no1', 'no2', 'Director', 'Genre']

# %%
df#.drop('Other', axis=1, inplace=True)
# Out:
#                                                Name  Rate  \
# 0                                 Побег из Шоушенка   9.1
# 1                                      Зеленая миля   9.1
# 2                                      Форрест Гамп   8.9
# 3                                   Список Шиндлера   8.8
# 4                                               1+1   8.8
# ..                                              ...   ...
# 995  Голодные игры: Баллада о змеях и певчих птицах   0.0
# 996          Леди Баг и Супер-Кот: Пробуждение силы   0.0
# 997                                       Мегалодон   0.0
# 998                                      Люби снова   0.0
# 999                                            Флэш   0.0
#
#                                     Roles  Country     View    Year  Duration  \
# 0              Тим Роббинс, Морган Фриман      США  920 397  1994.0     142.0
# 1                   Том Хэнкс, Дэвид Морс      США  890 554  1999.0     189.0
# ...

# %%
df.drop('no1', axis=1, inplace=True)
df.drop('no2', axis=1, inplace=True)

# %%
df
# Out:
#                                                Name  Rate  \
# 0                                 Побег из Шоушенка   9.1
# 1                                      Зеленая миля   9.1
# 2                                      Форрест Гамп   8.9
# 3                                   Список Шиндлера   8.8
# 4                                               1+1   8.8
# ..                                              ...   ...
# 995  Голодные игры: Баллада о змеях и певчих птицах   0.0
# 996          Леди Баг и Супер-Кот: Пробуждение силы   0.0
# 997                                       Мегалодон   0.0
# 998                                      Люби снова   0.0
# 999                                            Флэш   0.0
#
#                                     Roles  Country     View    Year  Duration  \
# 0              Тим Роббинс, Морган Фриман      США  920 397  1994.0     142.0
# 1                   Том Хэнкс, Дэвид Морс      США  890 554  1999.0     189.0
# ...

# %%
df.to_csv('result.csv')

# %%
df.to_pickle('result.pkl')
